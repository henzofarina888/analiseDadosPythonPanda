# %%
animais =[1,2,3,45]

# %%
animais = ["henzo", "leo", "pedrao",1,2,3]

# %%
animais[3]
# Out:
# 1

# %%
animais
# Out:
# ['henzo', 'leo', 'pedrao', 1, 2, 3]

# %%
animais.remove("leo")
animais
# Out:
# ['henzo', 'pedrao', 1, 2, 3]

# %%
len(animais)
# Out:
# 5

# %%
"leo " in animais
# Out:
# False

# %%
animais
# Out:
# ['henzo', 'pedrao', 1, 2, 3]

# %%
lista1=[1,2,3,4,5,7,4,56,4]

# %%
max(lista1)
# Out:
# 56

# %%
min(lista1)
# Out:
# 1

# %%
animais.append("henzo farina")
animais
# Out:
# ['henzo', 'pedrao', 1, 2, 3, 'henzo farina']

# %%
animais.extend(["cobra", "tigre", 182])

# %%
animais
# Out:
# ['henzo', 'pedrao', 1, 2, 3, 'henzo farina', 'cobra', 'tigre', 182]

# %%
animais[2]
# Out:
# 1

# %%
animais.remove("pedrao")

# %%
animais.remove(1)

# %%
animais.remove(2)

# %%
animais.remove(3)

# %%
animais.remove("henzo")

# %%
animais
# Out:
# ['henzo farina', 'cobra', 'tigre', 182]

# %%
animais.count("cobra")
# Out:
# 1

# %%
lista1.sort()
lista1
# Out:
# [1, 2, 3, 4, 4, 4, 5, 7, 56]

# %% [markdown]
# # Tuplas

# %%
tp =("banana", "maça", 10, 50)

# %%
tp[0]
# Out:
# 'banana'

# %%
tp[0]="henzo"
tp[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-0b4e322de996> in <module>
# ----> 1 tp[0]="henzo"
#       2 tp[0]
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Dicionários

# %%
dc = {"maça":20, "banana":10, "laranja":15, "uva":5}

# %%
dc
# Out:
# {'maça': 20, 'banana': 10, 'laranja': 15, 'uva': 5}

# %%
dc["maça"]
# Out:
# 20

# %%
total = dc["maça"] + dc["banana"]
total
# Out:
# 30

# %%
dc.keys()
# Out:
# dict_keys(['maça', 'banana', 'laranja', 'uva'])

# %%
dc.values()
# Out:
# dict_values([20, 10, 15, 5])

# %%
dc.setdefault("limão",15)
dc
# Out:
# {'maça': 20, 'banana': 10, 'laranja': 15, 'uva': 5, 'limão': 15}
