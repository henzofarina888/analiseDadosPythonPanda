# %%
frase = "henzo farina ciêntista de dados"

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'henzo farina ciêntista de dados'

# %%
frase.upper()
# Out:
# 'HENZO FARINA CIÊNTISTA DE DADOS'

# %%
frase.replace("ciêntista de dados", "programador")
# Out:
# 'henzo farina programador'
