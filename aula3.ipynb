# %%
import pandas as pds

# %%
df = pds.read_csv("/content/drive/MyDrive/gapminder.csv", error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#      continete continent   ano  expectativa de vida  população   gdpPercap
# 0  Afghanistan      Asia  1952               28.801    8425333  779.445314
# 1  Afghanistan      Asia  1957               30.332    9240934  820.853030
# 2  Afghanistan      Asia  1962               31.997   10267083  853.100710
# 3  Afghanistan      Asia  1967               34.020   11537966  836.197138
# 4  Afghanistan      Asia  1972               36.088   13079460  739.981106

# %%
df = df.rename(columns={"continete":"país","continent":"continente","year":"ano","lifeExp":"expectativa de vida","pop":"população","gdpPercap":"PIB"})

# %%
df.head(10)
# Out:
#           país continente   ano  expectativa de vida  população         PIB
# 0  Afghanistan       Asia  1952               28.801    8425333  779.445314
# 1  Afghanistan       Asia  1957               30.332    9240934  820.853030
# 2  Afghanistan       Asia  1962               31.997   10267083  853.100710
# 3  Afghanistan       Asia  1967               34.020   11537966  836.197138
# 4  Afghanistan       Asia  1972               36.088   13079460  739.981106
# 5  Afghanistan       Asia  1977               38.438   14880372  786.113360
# 6  Afghanistan       Asia  1982               39.854   12881816  978.011439
# 7  Afghanistan       Asia  1987               40.822   13867957  852.395945
# 8  Afghanistan       Asia  1992               41.674   16317921  649.341395
# 9  Afghanistan       Asia  1997               41.763   22227415  635.341351

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['país', 'continente', 'ano', 'expectativa de vida', 'população',
#        'gdpPercap'],
#       dtype='object')

# %%
df.dtypes
# Out:
# país                    object
# continente              object
# ano                      int64
# expectativa de vida    float64
# população                int64
# PIB                    float64
# dtype: object

# %%
df.tail()
# Out:
#           país continente   ano  expectativa de vida  população         PIB
# 1699  Zimbabwe     Africa  1987               62.351    9216418  706.157306
# 1700  Zimbabwe     Africa  1992               60.377   10704340  693.420786
# 1701  Zimbabwe     Africa  1997               46.809   11404948  792.449960
# 1702  Zimbabwe     Africa  2002               39.989   11926563  672.038623
# 1703  Zimbabwe     Africa  2007               43.487   12311143  469.709298

# %%
df.describe()
# Out:
#               ano  expectativa de vida     população            PIB
# count  1704.00000          1704.000000  1.704000e+03    1704.000000
# mean   1979.50000            59.474439  2.960121e+07    7215.327081
# std      17.26533            12.917107  1.061579e+08    9857.454543
# min    1952.00000            23.599000  6.001100e+04     241.165876
# 25%    1965.75000            48.198000  2.793664e+06    1202.060309
# 50%    1979.50000            60.712500  7.023596e+06    3531.846988
# 75%    1993.25000            70.845500  1.958522e+07    9325.462346
# max    2007.00000            82.603000  1.318683e+09  113523.132900

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ano                    1.979500e+03
# expectativa de vida    5.947444e+01
# população              2.960121e+07
# PIB                    7.215327e+03
# dtype: float64

# %%
df["continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
oceania= df.loc[df["continente"]=="Oceania"]

# %%
oceania
# Out:
#              país continente   ano  expectativa de vida  população  \
# 60      Australia    Oceania  1952               69.120    8691212
# 61      Australia    Oceania  1957               70.330    9712569
# 62      Australia    Oceania  1962               70.930   10794968
# 63      Australia    Oceania  1967               71.100   11872264
# 64      Australia    Oceania  1972               71.930   13177000
# 65      Australia    Oceania  1977               73.490   14074100
# 66      Australia    Oceania  1982               74.740   15184200
# 67      Australia    Oceania  1987               76.320   16257249
# 68      Australia    Oceania  1992               77.560   17481977
# 69      Australia    Oceania  1997               78.830   18565243
# 70      Australia    Oceania  2002               80.370   19546792
# 71      Australia    Oceania  2007               81.235   20434176
# 1092  New Zealand    Oceania  1952               69.390    1994794
# ...

# %%
df.groupby("continente")["país"].nunique()
# Out:
# continente
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: país, dtype: int64

# %%
df.groupby("ano")["expectativa de vida"].mean()
# Out:
# ano
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: expectativa de vida, dtype: float64

# %%
df["PIB"].mean()
# Out:
# 7215.327081211972

# %%
df["PIB"].sum()
# Out:
# 12294917.3463852
